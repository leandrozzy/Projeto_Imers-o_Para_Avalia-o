# %% [markdown]
# <a href="https://colab.research.google.com/github/leandrozzy/Projeto_Imersao/blob/main/Busca_dos_melhor_Jogo_de_cada_ano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Iniciando

# %%
# !pip install -q -U google.generativeai

# %%
import numpy as np
import pandas as pd
import google.generativeai as genai

from google.colab import userdata

api_key = userdata.get('CHAVE_SECRETA')

genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %% [markdown]
# Lista de Jogos

# %%
DOCUMENT1 = {
    "Ano": "1972",
    "Console": "Atari 2600, Magnavox Odyssey",
    "Jogos": "Pong"
}

DOCUMENT2 = {
    "Ano": "1973",
    "Console": "Atari 2600",
    "Jogos": "Pong"
}

DOCUMENT3 = {
    "Ano": "1974",
    "Console": "Sem jogo do ano",
    "Jogos": "Sem jogo do ano"
}

DOCUMENT4 = {
    "Ano": "1975",
    "Console": "Sem jogo do ano",
    "Jogos": "Sem jogo do ano"
}

DOCUMENT21 = {
    "Ano": "1976",
    "Console": "Sem jogo do ano",
    "Jogos": "Sem jogo do ano"
}

DOCUMENT5 = {
    "Ano": "1977",
    "Console": "Atari 2600",
    "Jogos": "Combat, Space Invaders"
}

DOCUMENT6 = {
    "Ano": "1978",
    "Console": "Atari 2600",
    "Jogos": "Space Invaders"
}

DOCUMENT7 = {
    "Ano": "1979",
    "Console": "Atari 2600",
    "Jogos": "Asteroids"
}
DOCUMENT8 = {
    "Ano": "1980",
    "Console": "Atari 2600",
    "Jogos": "Pac-Man"
}
DOCUMENT9 = {
    "Ano": "1981",
    "Console": "Atari 2600",
    "Jogos": "Donkey Kong"
}
DOCUMENT10 = {
    "Ano": "1982",
    "Console": "Atari 2600",
    "Jogos": "E.T. the Extra-Terrestrial"
}
DOCUMENT11 = {
    "Ano": "1983",
    "Console": "NES",
    "Jogos": "Super Mario Bros."
}
DOCUMENT12 = {
    "Ano": "1984",
    "Console": "NES",
    "Jogos": "The Legend of Zelda"
}
DOCUMENT13 = {
    "Ano": "1985",
    "Console": "NES",
    "Jogos": "Super Mario Bros. 2"
}
DOCUMENT14 = {
    "Ano": "1986",
    "Console": "NES",
    "Jogos": "Metroid"
}
DOCUMENT15 = {
    "Ano": "1987",
    "Console": "NES",
    "Jogos": "The Legend of Zelda: A Link to the Past"
}
DOCUMENT16 = {
    "Ano": "1988",
    "Console": "Sega Genesis",
    "Jogos": "Super Sonic Bros."
}
DOCUMENT17 = {
    "Ano": "1989",
    "Console": "NES",
    "Jogos": "Tetris"
}
DOCUMENT18 = {
    "Ano": "1990",
    "Console": "SNES",
    "Jogos": "Super Mario World"
}
DOCUMENT19 = {
    "Ano": "1991",
    "Console": "SNES",
    "Jogos": "The Legend of Zelda: A Link to the Past"
}
DOCUMENT20 = {
    "Ano": "1992",
    "Console": "SNES",
    "Jogos": "Super Mario Kart"
}

DOCUMENT22 = {
    "Ano": "1993",
    "Console": "SNES",
    "Jogos": "Star Fox"
}
DOCUMENT23 = {
    "Ano": "1994",
    "Console": "SNES",
    "Jogos": "Donkey Kong Country"
}
DOCUMENT24 = {
    "Ano": "1995",
    "Console": "Sony PlayStation",
    "Jogos": "Crash Bandicoot"
}
DOCUMENT25 = {
    "Ano": "1996",
    "Console": "Nintendo 64",
    "Jogos": "Super Mario 64"
}
DOCUMENT26 = {
    "Ano": "1997",
    "Console": "Nintendo 64",
    "Jogos": "The Legend of Zelda: Ocarina of Time"
}

DOCUMENT28 = {
    "Ano": "1998",
    "Console": "Nintendo 64",
    "Jogos": "Star Fox 64"
}
DOCUMENT29 = {
    "Ano": "1999",
    "Console": "Nintendo 64",
    "Jogos": "The Legend of Zelda: Majora's Mask"
}

DOCUMENT31 = {
    "Ano": "2000",
    "Console": "PlayStation 2",
    "Jogos": "Grand Theft Auto III"
}
DOCUMENT32 = {
    "Ano": "2001",
    "Console": "GameCube",
    "Jogos": "Super Smash Bros. Melee"
}
DOCUMENT33 = {
    "Ano": "2002",
    "Console": "Xbox",
    "Jogos": "Halo: Combat Evolved"
}
DOCUMENT34 = {
    "Ano": "2003",
    "Console": "GameCube",
    "Jogos": "The Legend of Zelda: The Wind Waker"
}

DOCUMENT36 = {
    "Ano": "2004",
    "Console": "PlayStation 2",
    "Jogos": "Metal Gear Solid 3: Snake Eater"
}
DOCUMENT37 = {
    "Ano": "2005",
    "Console": "Xbox 360",
    "Jogos": "Halo 2"
}
DOCUMENT38 = {
    "Ano": "2006",
    "Console": "PlayStation 3",
    "Jogos": "Gears of War"
}
DOCUMENT39 = {
    "Ano": "2007",
    "Console": "Wii",
    "Jogos": "Super Mario Galaxy"
}
DOCUMENT40 = {
    "Ano": "2008",
    "Console": "PlayStation 3",
    "Jogos": "Metal Gear Solid 4: Guns of the Patriots"
}
DOCUMENT41 = {
    "Ano": "2009",
    "Console": "Xbox 360",
    "Jogos": "Left 4 Dead 2"
}
DOCUMENT42 = {
    "Ano": "2010",
    "Console": "PlayStation 3",
    "Jogos": "God of War III"
}
DOCUMENT43 = {
    "Ano": "2011",
    "Console": "Nintendo 3DS",
    "Jogos": "The Legend of Zelda: Ocarina of Time 3D"
}
DOCUMENT44 = {
    "Ano": "2012",
    "Console": "PlayStation 4",
    "Jogos": "The Last of Us"
}
DOCUMENT27 = {
    "Ano": "2013",
    "Console": "PlayStation 4",
    "Jogos": "The Last of Us"
}

DOCUMENT45 = {
    "Ano": "2014",
    "Console": "PlayStation 4",
    "Jogos": "Grand Theft Auto V"
}
DOCUMENT46 = {
    "Ano": "2015",
    "Console": "PC",
    "Jogos": "The Witcher 3: Wild Hunt"
}
DOCUMENT47 = {
    "Ano": "2016",
    "Console": "PlayStation 4",
    "Jogos": "Uncharted 4: A Thief's End"
}
DOCUMENT48 = {
    "Ano": "2017",
    "Console": "Nintendo Switch",
    "Jogos": "The Legend of Zelda"
}
DOCUMENT49 = {
    "Ano": "2018",
    "Console": "PlayStation 4",
    "Jogos": "God of War"
}
DOCUMENT50 = {
    "Ano": "2019",
    "Console": "Nintendo Switch",
    "Jogos": "Super Mario Odyssey"
}
DOCUMENT51 = {
    "Ano": "2020",
    "Console": "PlayStation 5",
    "Jogos": "The Last of Us Part II"
}
DOCUMENT52 = {
    "Ano": "2021",
    "Console": "Nintendo Switch",
    "Jogos": "Metroid Dread"
}
DOCUMENT35 = {
    "Ano": "2022",
    "Console": "PlayStation 5",
    "Jogos": "Elden Ring"
}


DOCUMENT30 = {
    "Ano": "2023",
    "Console": "Xbox Series X/S",
    "Jogos": "Starfield"
}



documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3, DOCUMENT4, DOCUMENT21, DOCUMENT5, DOCUMENT6, DOCUMENT7, DOCUMENT8, DOCUMENT9, DOCUMENT10, DOCUMENT11, DOCUMENT12, DOCUMENT13, DOCUMENT14, DOCUMENT15, DOCUMENT16, DOCUMENT17, DOCUMENT18, DOCUMENT19, DOCUMENT20, DOCUMENT22, DOCUMENT23, DOCUMENT24, DOCUMENT25, DOCUMENT26, DOCUMENT28, DOCUMENT29, DOCUMENT31, DOCUMENT32, DOCUMENT33, DOCUMENT34, DOCUMENT36, DOCUMENT37, DOCUMENT38, DOCUMENT39, DOCUMENT40, DOCUMENT41, DOCUMENT42, DOCUMENT43, DOCUMENT44, DOCUMENT27, DOCUMENT45, DOCUMENT46, DOCUMENT47, DOCUMENT48, DOCUMENT49, DOCUMENT50, DOCUMENT51, DOCUMENT52, DOCUMENT35, DOCUMENT30]



#documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3]

# %% [markdown]
# Tabela

# %%
df = pd.DataFrame(documents)
df
# Out:
#      Ano                       Console  \
# 0   1972  Atari 2600, Magnavox Odyssey
# 1   1973                    Atari 2600
# 2   1974               Sem jogo do ano
# 3   1975               Sem jogo do ano
# 4   1976               Sem jogo do ano
# 5   1977                    Atari 2600
# 6   1978                    Atari 2600
# 7   1979                    Atari 2600
# 8   1980                    Atari 2600
# 9   1981                    Atari 2600
# 10  1982                    Atari 2600
# 11  1983                           NES
# 12  1984                           NES
# 13  1985                           NES
# 14  1986                           NES
# 15  1987                           NES
# 16  1988                  Sega Genesis
# 17  1989                           NES
# 18  1990                          SNES
# 19  1991                          SNES
# 20  1992                          SNES
# 21  1993                          SNES
# 22  1994                          SNES
# ...

# %% [markdown]
# Buscar Tabela

# %%
df = pd.DataFrame(documents)
#Nomeia as colunas
df.columns = ["Ano", "Console", "Jogos"]
df
# Out:
#      Ano                       Console  \
# 0   1972  Atari 2600, Magnavox Odyssey
# 1   1973                    Atari 2600
# 2   1974               Sem jogo do ano
# 3   1975               Sem jogo do ano
# 4   1976               Sem jogo do ano
# 5   1977                    Atari 2600
# 6   1978                    Atari 2600
# 7   1979                    Atari 2600
# 8   1980                    Atari 2600
# 9   1981                    Atari 2600
# 10  1982                    Atari 2600
# 11  1983                           NES
# 12  1984                           NES
# 13  1985                           NES
# 14  1986                           NES
# 15  1987                           NES
# 16  1988                  Sega Genesis
# 17  1989                           NES
# 18  1990                          SNES
# 19  1991                          SNES
# 20  1992                          SNES
# 21  1993                          SNES
# 22  1994                          SNES
# ...

# %%
model = "models/embedding-001"

# %% [markdown]
# Tratamento de embedding

# %%
def embed_fn(title, text):
  return genai.embed_content(model=model,
                                content=text,
                                title=title,
                                task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %% [markdown]
# Acessar dataframe e inserir coluna do embedding

# %%
df["Embeddings"] = df.apply(lambda row: embed_fn(row["Ano"], row["Jogos"]), axis=1)
df
# Out:
#      Ano                       Console  \
# 0   1972  Atari 2600, Magnavox Odyssey
# 1   1973                    Atari 2600
# 2   1974               Sem jogo do ano
# 3   1975               Sem jogo do ano
# 4   1976               Sem jogo do ano
# 5   1977                    Atari 2600
# 6   1978                    Atari 2600
# 7   1979                    Atari 2600
# 8   1980                    Atari 2600
# 9   1981                    Atari 2600
# 10  1982                    Atari 2600
# 11  1983                           NES
# 12  1984                           NES
# 13  1985                           NES
# 14  1986                           NES
# 15  1987                           NES
# 16  1988                  Sega Genesis
# 17  1989                           NES
# 18  1990                          SNES
# 19  1991                          SNES
# 20  1992                          SNES
# 21  1993                          SNES
# 22  1994                          SNES
# ...

# %% [markdown]
# Contruir estrutura para buscar os documentos

# %%
def gerar_buscar_consulta(consulta, base, model):
  embedding_consulta = genai.embed_content(model=model,
                                content=consulta,
                                task_type="RETRIEVAL_QUERY")["embedding"]

  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_consulta)

  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Jogos"]

# %% [markdown]
# Realizar Consulta

# %%
consulta = "1986"
trecho = gerar_buscar_consulta(consulta, df, model)
print(trecho)
# Out:
# Metroid

# %% [markdown]
# Pergunta inteligente

# %%
prompt = f"Diga o console, o ano de lançamento e a história do jogo que é indicado pelo trecho: {trecho}"

model_2 = genai.GenerativeModel("gemini-1.0-pro",
                                generation_config=generation_config)
response = model_2.generate_content(prompt)
print(response.text)
# Out:
# **Console:** Nintendo Entertainment System (NES)
# **Ano de Lançamento:** 1986
#
# **História:**
#
# Metroid é um jogo de ação e aventura side-scrolling ambientado no planeta fictício Zebes. O jogador controla a caçadora de recompensas Samus Aran, que é enviada para Zebes para destruir os Metroids, criaturas perigosas que podem consumir a energia vital de seres vivos.
#
# À medida que Samus explora Zebes, ela encontra vários obstáculos e inimigos, incluindo os perigosos Chefes do Metroid. Ao derrotar os Chefes, Samus ganha novas habilidades que lhe permitem acessar novas áreas do planeta e progredir em sua missão.
#
# A história do jogo se desenrola através de diálogos e textos espalhados pelo mundo do jogo. É revelado que os Metroids foram criados por uma raça antiga chamada Chozo para serem armas biológicas. No entanto, os Metroids escaparam do controle dos Chozo e começaram a se espalhar por Zebes.
#
# ...
